# %% [markdown]
# <a href="https://colab.research.google.com/github/anilrajr-irs/GCOL/blob/main/Firrst__GCOL_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Niranjana")
# Out:
# Hello Niranjana

# %%
3+5
# Out:
# 8

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# # New section

# %%
import pandas as pd

# %%
# !git clone
# Out:
# fatal: You must specify a repository to clone.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recursive ...       alias of --recurse-submodules
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
#     --reference <repo>    reference repository
# ...

# %%
pd.read_csv('/content/sample_data/california_housing_train.csv').head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
pd.read_xlsx('"C:\\Users\\CBIC\\Desktop\\FinalReportCb.xlsx"').head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-487ed07a9d72> in <cell line: 1>()
# ----> 1 pd.read_xlsx('"C:\\Users\\CBIC\\Desktop\\FinalReportCb.xlsx"').head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
pd.read_pyxl('"C:\\Users\\CBIC\\Desktop\\FinalReportCb.xlsx"').head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-df915e050510> in <cell line: 1>()
# ----> 1 pd.read_pyxl('"C:\\Users\\CBIC\\Desktop\\FinalReportCb.xlsx"').head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'read_pyxl'

# %% [markdown]
# ![4jan.png](data:image/png;base64,...)

# %%
https://colab.research.google.com/drive/1AbibEHbnB2tOE_ixvOgQ6BMlYe4xNXO7#scrollTo=Zy-VzfjikA9H&line=1&uniqifier=1
# Out:
#   File "<ipython-input-15-7a864b517f6f>", line 1
#     https://colab.research.google.com/drive/1AbibEHbnB2tOE_ixvOgQ6BMlYe4xNXO7#scrollTo=Zy-VzfjikA9H&line=1&uniqifier=1
#                                             ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# [link text](https://www.google.com)

# %% [markdown]
# [Google Search](https://www.google.com) text

# %% [markdown]
# $$x1=\frac{-b+\sqrt{b^2-4ac}}{2a}$$
